# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from geopy.geocoders import Nominatim
import time
from geopy.distance import great_circle
import folium
import plotly.express as px

# %%
# Mapping of cities to their respective departments
department_mapping_benin = {
    'Kandi': 'Alibori',
    'Natitingou': 'Atakora',
    'Ouidah': 'Atlantique',
    'Parakou': 'Borgou',
    'Savalou': 'Collines',
    'Dogbo-Tota': 'Couffo',
    'Djougou': 'Donga',
    'Cotonou': 'Littoral',
    'Lokossa': 'Mono',
    'Porto-Novo': 'Oueme',
    'Sakété': 'Plateau',
    'Abomey': 'Zou'
}

# Mapping of cities to their respective departments in Togo
department_mapping_togo = {
    'Lomé': 'Maritime',
    'Kara': 'Kara',
    'Sokodé': 'Centrale',
    'Atakpamé': 'Plateaux',
    'Dapaong': 'Savanes_Togo'
}

department_mapping_civ = {
    'Abidjan': 'Abidjan',
    'San-Pédro': 'Bas-Sassandra',
    'Abengourou': 'Comoé',
    'Odienné': 'District du Denguélé',
    'Gagnoa': 'Gôh-Djiboua',
    'Yamoussoukro': 'Yamoussoukro',
    'Dimbokro': 'Lacs',
    'Dabou': 'Lagunes',
    'Man': 'Montagnes',
    'Daloa': 'Sassandra-Marahoué',
    'Korhogo': 'Savanes_CIV',
    'Bouaké': 'Vallée du Bandama',
    'Séguéla': 'Woroba',
    'Bondoukou': 'Zanzan'
}

# %%
# Define the coordinates for each city in Benin
coordinates_benin = {
    'Kandi': (11.13, 2.94),
    'Natitingou': (10.32, 1.38),
    'Ouidah': (6.37, 2.08),
    'Parakou': (9.34, 2.63),
    'Savalou': (8.03, 1.97),
    'Dogbo-Tota': (6.73, 1.78),
    'Djougou': (9.69, 1.57),
    'Cotonou': (6.37, 2.43),
    'Lokossa': (6.64, 1.72),
    'Porto-Novo': (6.47, 2.61),
    'Sakété': (6.74, 2.67),
    'Abomey': (7.18, 2.05)
}

# Define the coordinates for the five capitals of regions in Togo :
coordinates_togo = {
    'Lomé': (6.13, 1.22),
    'Kara': (9.55, 1.19),
    'Sokodé': (8.99, 1.13),
    'Atakpamé': (7.53, 1.13),
    'Dapaong': (10.86, 0.20)
}

# Définir les coordonnées pour chaque district en Côte d'Ivoire
coordinates_civ = {
    'Abidjan': (5.32, -4.03),
    'Bas-Sassandra': (4.95, -6.08),
    'Comoé': (5.18, -3.28),
    'District du Denguélé': (9.59, -7.54),
    'Gôh-Djiboua': (6.07, -5.94),
    'Lacs': (6.81, -5.18),
    'Lagunes': (5.90, -3.93),
    'Montagnes': (7.38, -7.56),
    'Sassandra-Marahoué': (6.21, -5.90),
    'Savanes_CIV': (9.41, -5.63),
    'Vallée du Bandama': (7.70, -5.03),
    'Woroba': (8.22, -6.49),
    'Yamoussoukro': (6.82, -5.27),
    'Zanzan': (8.06, -2.78)
}


'''

# Initialize the geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

# Function to get coordinates for a given location
def get_coordinates(location):
    try:
        location_data = geolocator.geocode(location)
        if location_data:
            return (location_data.latitude, location_data.longitude)
        else:
            return None
    except Exception as e:
        print(f"Error fetching coordinates for {location}: {e}")
        return None

# Compute and store the coordinates
coordinates_benin = {}
for city in department_mapping_benin.keys():
    location = f"{city}, Benin"
    #print(location)
    coords = get_coordinates(location)
    if coords:
        coordinates_benin[city] = coords
        print(f"{city}: {coords}")
    else:
        print(f"Coordinates for {city} not found.")
    
    # Be polite to the server and avoid making requests too quickly
    time.sleep(1)

coordinates_togo = {}
for city in department_mapping_togo.keys():
    location = f"{city}, Togo"
    #print(location)
    coords = get_coordinates(location)
    if coords:
        coordinates_togo[city] = coords
        print(f"{city}: {coords}")
    else:
        print(f"Coordinates for {city} not found.")
    
    # Be polite to the server and avoid making requests too quickly
    time.sleep(1)

# Initialize the geocoder
geolocator = Nominatim(user_agent="geoapiExercises")

coordinates_civ = {}
for city in department_mapping_civ.keys():
    location = f"{city}, Côte d'Ivoire"
    #print(location)
    coords = get_coordinates(location)
    if coords:
        coordinates_civ[city] = coords
        print(f"{city}: {coords}")
    else:
        print(f"Coordinates for {city} not found.")
    
    # Be polite to the server and avoid making requests too quickly
    time.sleep(1)
'''
# Out:
# '\n\n# Initialize the geocoder\ngeolocator = Nominatim(user_agent="geoapiExercises")\n\n# Function to get coordinates for a given location\ndef get_coordinates(location):\n    try:\n        location_data = geolocator.geocode(location)\n        if location_data:\n            return (location_data.latitude, location_data.longitude)\n        else:\n            return None\n    except Exception as e:\n        print(f"Error fetching coordinates for {location}: {e}")\n        return None\n\n# Compute and store the coordinates\ncoordinates_benin = {}\nfor city in department_mapping_benin.keys():\n    location = f"{city}, Benin"\n    #print(location)\n    coords = get_coordinates(location)\n    if coords:\n        coordinates_benin[city] = coords\n        print(f"{city}: {coords}")\n    else:\n        print(f"Coordinates for {city} not found.")\n    \n    # Be polite to the server and avoid making requests too quickly\n    time.sleep(1)\n\ncoordinates_togo = {}\nfor city in department_mappin
# ...

# %%
# Compute distances for Benin cities
neighbors_benin = {}

for city1, coords1 in coordinates_benin.items():
    neighbors_benin[city1] = {}
    for city2, coords2 in coordinates_benin.items():
        if city1 != city2:
            distance = great_circle(coords1, coords2).kilometers
            neighbors_benin[city1][city2] = distance
            #print(f"{city1} : {city2} = {distance:.2f}")

# Compute distances for Togo cities
neighbors_togo = {}

for city1, coords1 in coordinates_togo.items():
    neighbors_togo[city1] = {}
    for city2, coords2 in coordinates_togo.items():
        if city1 != city2:
            distance = great_circle(coords1, coords2).kilometers
            neighbors_togo[city1][city2] = distance
            #print(f"{city1} : {city2} = {distance:.2f}")


neighbors_civ = {}

for city1, coords1 in coordinates_civ.items():
    neighbors_civ[city1] = {}
    for city2, coords2 in coordinates_civ.items():
        if city1 != city2:
            distance = great_circle(coords1, coords2).kilometers
            neighbors_civ[city1][city2] = distance
            print(f"{city1} : {city2} = {distance:.2f}")
# Out:
# Abidjan : Bas-Sassandra = 230.73
# Abidjan : Comoé = 84.49
# Abidjan : District du Denguélé = 612.48
# Abidjan : Gôh-Djiboua = 227.19
# Abidjan : Lacs = 208.85
# Abidjan : Lagunes = 65.44
# Abidjan : Montagnes = 452.37
# Abidjan : Sassandra-Marahoué = 229.33
# Abidjan : Savanes_CIV = 487.80
# Abidjan : Vallée du Bandama = 286.78
# Abidjan : Woroba = 421.61
# Abidjan : Yamoussoukro = 215.91
# Abidjan : Zanzan = 334.48
# Bas-Sassandra : Abidjan = 230.73
# Bas-Sassandra : Comoé = 311.18
# Bas-Sassandra : District du Denguélé = 540.48
# Bas-Sassandra : Gôh-Djiboua = 125.50
# Bas-Sassandra : Lacs = 229.53
# Bas-Sassandra : Lagunes = 260.39
# Bas-Sassandra : Montagnes = 315.87
# Bas-Sassandra : Sassandra-Marahoué = 141.51
# Bas-Sassandra : Savanes_CIV = 498.41
# Bas-Sassandra : Vallée du Bandama = 327.06
# Bas-Sassandra : Woroba = 366.42
# Bas-Sassandra : Yamoussoukro = 226.41
# Bas-Sassandra : Zanzan = 502.47
# Comoé : Abidjan = 84.49
# Comoé : Bas-Sassandra = 311.18
# ...

# %%
# Define the number of agencies in each city
nb_agencies_benin = {
    'Kandi': 5,
    'Natitingou': 3,
    'Ouidah': 17,
    'Parakou': 13,
    'Savalou': 4,
    'Dogbo-Tota': 1,
    'Djougou': 1,
    'Cotonou': 121,
    'Lokossa': 7,
    'Porto-Novo': 19,
    'Sakété': 0,
    'Abomey': 11
}

# Define the number of agencies in each city in Togo
nb_agencies_togo = {
    'Kara': 19,
    'Sokodé': 10,
    'Atakpamé': 16,
    'Lomé': 112,
    'Dapaong': 19
}

# Définir le nombre d'agences pour chaque district
nb_agencies_civ = {
    'Abidjan': 396,
    'Bas-Sassandra': 40,
    'Comoé': 27,
    'District du Denguélé': 2,
    'Gôh-Djiboua': 20,
    'Lacs': 8,
    'Lagunes': 15,
    'Montagnes': 15,
    'Sassandra-Marahoué': 23,
    'Savanes_CIV': 24,
    'Vallée du Bandama': 20,
    'Woroba': 4,
    'Yamoussoukro': 11,
    'Zanzan': 1
}

# %%
"""ISIBF score for each city"""

# Function to calculate ISIBF

def calculate_isibf1(num_agencies, neighbors, alpha, threshold):
    isibf_values = {}

    for city in num_agencies:
        total = 0
        for neighbor, distance in neighbors[city].items():
            if distance <= threshold:
                total += np.log2(num_agencies[neighbor]+1) / alpha**distance
        total+= np.log2(num_agencies[city] +1)

        isibf_values[city] = total

    return isibf_values

def calculate_isibf0(city_counts, neighbors, alpha, threshold):
    contributions_voisins={}
    contribution_propre={}
    isibf_values = {}
    for city in city_counts:
        total = 0
        for neighbor, distance in neighbors[city].items():
            if distance <= threshold:
                total += np.log2(city_counts[neighbor] + 1) / alpha**distance
            else:
                total += 0
        #print(f"{city_to_region[city]}, contribution des voisins = {total:.2f}, contribution propre = {(city_counts[city] + 1):.2f}")
        if city_counts[city] == 1: #changement
            contribution_propre[city] = 1 #changement
        elif city_counts[city] == 0: #changement
            contribution_propre[city] = 0
        else: 
            contribution_propre[city] = np.log2(city_counts[city]) #changement
        contributions_voisins[city] = total
        total+= np.log2(city_counts[city] + 1)
        isibf_values[city] = total
    return contribution_propre, contributions_voisins, isibf_values

def normalize_scores(scores):
    min_score = min(scores.values())
    max_score = max(scores.values())
    return {city: (score - min_score) / (max_score - min_score) for city, score in scores.items()}

# %%
benin = gpd.read_file('/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/Dashboard/ben_adm_1m_salb_2019_shapes')
togo = gpd.read_file('/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/Dashboard/Shapefiles_togo')
civ = gpd.read_file("/Users/haouabenaliabbo/Downloads/202303_OSM2IGEO_COTE_D_IVOIRE_SHP_WGS84_4326/H_OSM_ADMINISTRATIF/DISTRICT.shp")

# Togo
togo['ADM1_REF'] = 'Togo'

# Côte d'Ivoire
civ['ID'] = "Côte d'Ivoire"

benin = benin.rename(columns={'adm0_name': 'country'})
togo = togo.rename(columns={'ADM1_FR': 'adm1_name'})
togo = togo.rename(columns={'ADM1_REF': 'country'})
civ = civ.rename(columns={'NOM':'adm1_name'})
civ = civ.rename(columns={'ID':'country'})

togo['adm1_name'] = togo['adm1_name'].replace('Savanes', 'Savanes_Togo')
civ['adm1_name'] = civ['adm1_name'].replace('Savanes', 'Savanes_CIV')


# Fusionner les shapefiles en un seul GeoDataFrame
benin_togo_civ = pd.concat([benin, togo, civ], ignore_index=True)
benin_togo_civ=benin_togo_civ.rename(columns={'adm1_name': 'admin1Name'})
print(benin_togo_civ)
# Out:
#     OBJECTID_1            admin1Name        status        country  shape_Leng  \
# 0          1.0               Alibori  Member State          Benin    7.186700
# 1          2.0               Atakora  Member State          Benin    6.029807
# 2          3.0            Atlantique  Member State          Benin    3.252428
# 3          4.0                Borgou  Member State          Benin    7.733858
# 4          5.0              Collines  Member State          Benin    5.042533
# 5          6.0                Couffo  Member State          Benin    2.540471
# 6          7.0                 Donga  Member State          Benin    5.169964
# 7          8.0              Littoral  Member State          Benin    0.505867
# 8          9.0                  Mono  Member State          Benin    2.883128
# 9         10.0                 Oueme  Member State          Benin    2.179768
# 10        11.0               Plateau  Member State          Benin    3.111947
# ...

# %%
alpha_benin=1.04
threshold=200

contribution_propre_benin, contributions_voisins_benin, values_benin = calculate_isibf0(nb_agencies_benin, neighbors_benin, alpha_benin, threshold)

# apply np.ceil for contributions propres
#contribution_propre_benin = {k: np.floor(v) for k, v in contribution_propre_benin.items()}

print(contribution_propre_benin)



import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 8))

# Plot the contributions of neighbors
#ax.barh(list(contributions_voisins_benin.keys()), list(contributions_voisins_benin.values()), color='skyblue', label='Contribution des voisins Benin')

# Plot the contributions of the cities themselves
#ax.barh(list(contribution_propre_benin.keys()), list(contribution_propre_benin.values()), color='salmon', label='Contribution propre Benin')

ax.barh(list(values_benin.keys()), list(values_benin.values()), color='green', label='ISIBF')


# Add labels and title

ax.set_xlabel('Score')
ax.set_ylabel('Chef-Lieu')
ax.set_title('Contibutions aux scores')
ax.legend()

#same for togo alpha_togo=1.009

alpha_togo=1.01
contribution_propre_togo, contributions_voisins_togo, values_togo = calculate_isibf0(nb_agencies_togo, neighbors_togo, alpha_togo, threshold)
#contribution_propre_togo={k: np.floor(v) for k, v in contribution_propre_togo.items()}
print(contribution_propre_togo)
fig, ax = plt.subplots(figsize=(12, 8))

# Plot the contributions of neighbors
#ax.barh(list(contributions_voisins_togo.keys()), list(contributions_voisins_togo.values()), color='skyblue', label='Contribution des voisins Togo')

# Plot the contributions of the cities themselves
#ax.barh(list(contribution_propre_togo.keys()), list(contribution_propre_togo.values()), color='salmon', label='Contribution propre Togo')
ax.barh(list(values_togo.keys()), list(values_togo.values()), color='green', label='ISIBF')


# Add labels and title

ax.set_xlabel('Score')
ax.set_ylabel('Chef-Lieu')
ax.set_title('Contibutions aux scores')

ax.legend()

#same for civ

alpha_civ=1.02
contribution_propre_civ, contributions_voisins_civ, values_civ = calculate_isibf0(nb_agencies_civ, neighbors_civ, alpha_civ, threshold)
#contribution_propre_civ={k: np.floor(v) for k, v in contribution_propre_civ.items()}
print(contribution_propre_civ)
#use reverse mapping to get the scores of contributions propres to the regions




fig, ax = plt.subplots(figsize=(12, 8))

# Plot the contributions of neighbors

#ax.barh(list(contributions_voisins_civ.keys()), list(contributions_voisins_civ.values()), color='skyblue', label='Contribution des voisins Côte d\'Ivoire')

# Plot the contributions of the cities themselves starting from the end of the list
#ax.barh(list(contribution_propre_civ.keys()), list(contribution_propre_civ.values()), color='salmon', label='Contribution propre Côte d\'Ivoire')
ax.barh(list(values_civ.keys()), list(values_civ.values()), color='green', label='ISIBF')


# Add labels and title

ax.set_xlabel('Score')
ax.set_ylabel('Chef-Lieu')
ax.set_title('Contibutions aux scores')
ax.legend()

print({**values_benin, **values_togo, **values_civ})
# Out:
# {'Kandi': 2.321928094887362, 'Natitingou': 1.584962500721156, 'Ouidah': 4.087462841250339, 'Parakou': 3.700439718141092, 'Savalou': 2.0, 'Dogbo-Tota': 1, 'Djougou': 1, 'Cotonou': 6.918863237274595, 'Lokossa': 2.807354922057604, 'Porto-Novo': 4.247927513443585, 'Sakété': 0, 'Abomey': 3.4594316186372973}
# {'Kara': 4.247927513443585, 'Sokodé': 3.321928094887362, 'Atakpamé': 4.0, 'Lomé': 6.807354922057604, 'Dapaong': 4.247927513443585}
# {'Abidjan': 8.62935662007961, 'Bas-Sassandra': 5.321928094887363, 'Comoé': 4.754887502163468, 'District du Denguélé': 1.0, 'Gôh-Djiboua': 4.321928094887363, 'Lacs': 3.0, 'Lagunes': 3.9068905956085187, 'Montagnes': 3.9068905956085187, 'Sassandra-Marahoué': 4.523561956057013, 'Savanes_CIV': 4.584962500721156, 'Vallée du Bandama': 4.321928094887363, 'Woroba': 2.0, 'Yamoussoukro': 3.4594316186372973, 'Zanzan': 1}
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation



# Définir les valeurs de x
x = np.linspace(1.00001, 1.1, 400)  # On évite x=0 car cela entraînerait une division par zéro
y = 6.8*(x ** -200)  # Calculer y = x^(-200)

# Tracer le graphique
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='y = x^(-200)', color='blue')
plt.title('Graphique de la fonction y = x^(-200)')
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(0, 6.8)  # Limiter l'axe des ordonnées pour une meilleure visualisation
plt.xlim(1, 1.1)  # Limiter l'axe des abscisses
plt.axhline(0, color='black', linewidth=0.5, ls='--')
plt.axvline(0, color='black', linewidth=0.5, ls='--')
plt.grid()
plt.legend()
plt.show()

# %%
#map to departments for benin and togo
values_dep_benin = {department_mapping_benin[city]: score for city, score in values_benin.items()}
values_dep_togo = {department_mapping_togo[city]: score for city, score in values_togo.items()}


#normalize
values_benin_norm = normalize_scores(values_dep_benin)
values_togo_norm = normalize_scores(values_dep_togo)
values_civ_norm = normalize_scores(values_civ)

#Apply .2f decimal values for scores
values_benin_norm = {dep: round(score, 2) for dep, score in values_benin_norm.items()}
values_togo_norm = {dep: round(score, 2) for dep, score in values_togo_norm.items()}
values_civ_norm = {dep: round(score, 2) for dep, score in values_civ_norm.items()}


print(values_benin_norm)

# Combine the scores for Benin and Togo
scores_dep_combined_norm = {**values_benin_norm, **values_togo_norm, **values_civ_norm}
# Out:
# {'Alibori': 0.17, 'Atakora': 0.11, 'Atlantique': 0.65, 'Borgou': 0.31, 'Collines': 0.15, 'Couffo': 0.35, 'Donga': 0.0, 'Littoral': 1.0, 'Mono': 0.42, 'Oueme': 0.76, 'Plateau': 0.18, 'Zou': 0.36}

# %%
"""map Benin"""

#create a map centered on benin
my_map_benin = folium.Map(location=[9.5, 2.3], zoom_start=5)

print(benin.head())

benin.rename(columns={'adm1_name': 'admin1Name'}, inplace=True)

# Add the ISIBF scores to the GeoDataFrame

benin['ISIBF'] = benin['admin1Name'].map(values_benin_norm)


# Plot the map
folium.Choropleth(
    geo_data=benin,
    name='choropleth',
    data=benin,
    columns=['admin1Name', 'ISIBF'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    line_weight=2,
    legend_name='ISIBF score'
).add_to(my_map_benin)

# Add a tooltip to display information
folium.GeoJson(
    benin.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF'] is not None else 'gray',
        'color': 'grey',
        'weight': 0.5,
        'fillOpacity': 0.2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF'],
        aliases=['Region:', 'ISIBF Score:'],
        localize=True,
    )
).add_to(my_map_benin)

# Save the map as an HTML file
#my_map.save("/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/Dashboard/isibf_benin_togo_civ_norm.html")


#benin['ISIBF'] = benin['admin1Name'].map(values_benin_norm)

# Convert to GeoJSON
geojson_data = benin.__geo_interface__

fig = px.choropleth_mapbox(
    benin,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='ISIBF',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 9.5, "lon": 2.3},
    title="Score d'accès aux agences bancaires par régions au Bénin",
    hover_name="admin1Name",  # Region names
    hover_data={'ISIBF': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'ISIBF': 'ISIBF Score'},
    color_continuous_scale=px.colors.sequential.Blues,  # Light to dark blue color scale
)

# Save as HTML
#html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/isibf_benin.html'

# Save the map as HTML
#fig.write_html(html_file_path)
# Out:
#    OBJECTID_1   adm1_name        status country  shape_Leng        Type1 ISO3  \
# 0           1     Alibori  Member State   Benin    7.186700  Département  BEN
# 1           2     Atakora  Member State   Benin    6.029807  Département  BEN
# 2           3  Atlantique  Member State   Benin    3.252428  Département  BEN
# 3           4      Borgou  Member State   Benin    7.733858  Département  BEN
# 4           5    Collines  Member State   Benin    5.042533  Département  BEN
#
#    Shape_Le_1  Shape_Area admin1Pcod admin0Pcod  \
# 0    7.186700    2.228046       BJ01         BJ
# 1    6.029807    1.712848       BJ02         BJ
# 2    3.252428    0.245617       BJ03         BJ
# 3    7.733858    2.110006       BJ04         BJ
# 4    5.042533    1.149787       BJ05         BJ
#
#                                             geometry
# 0  POLYGON ((2.83915 12.40646, 2.84301 12.40350, ...
# 1  POLYGON ((1.44618 11.46488, 1.45155 11.46259, ...
# ...

# %%
# Create a map centered on Togo
my_map_togo = folium.Map(location=[8.5, 1.2], zoom_start=5)

print(togo.head())

togo.rename(columns={'adm1_name': 'admin1Name'}, inplace=True)

# Add the ISIBF scores to the GeoDataFrame
togo['ISIBF'] = togo['admin1Name'].map(values_togo_norm)

# Plot the map
folium.Choropleth(
    geo_data=togo,
    name='choropleth',
    data=togo,
    columns=['admin1Name', 'ISIBF'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    line_weight=2,
    legend_name='ISIBF score'
).add_to(my_map_togo)

# Add a tooltip to display information
folium.GeoJson(
    togo.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF'] is not None else 'gray',
        'color': 'grey',
        'weight': 0.5,
        'fillOpacity': 0.2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF'],
        aliases=['Region:', 'ISIBF Score:'],
        localize=True,
    )
).add_to(my_map_togo)



# Update the DataFrame for the combined map
#togo['ISIBF'] = togo['admin1Name'].map(values_togo_norm)

# Convert to GeoJSON
geojson_data = togo.__geo_interface__

# Plotly Choropleth Map for Togo
fig = px.choropleth_mapbox(
    togo,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='ISIBF',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 8.5, "lon": 1.2},  # Center on Togo
    title="Score d'accès aux agences bancaires par régions au Togo",
    hover_name="admin1Name",  # Region names
    hover_data={'ISIBF': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'ISIBF': 'ISIBF Score'},
    color_continuous_scale=px.colors.sequential.Blues,  # Light to dark blue color scale
)

# Save as HTML
#html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/isibf_togo.html'
#fig.write_html(html_file_path)
# Out:
#    Shape_Leng  Shape_Area     adm1_name ADM1_PCODE country ADM1ALT1FR  \
# 0    5.454335    1.077901      Centrale       TG01    Togo       None
# 1    5.891495    0.969494          Kara       TG02    Togo       None
# 2    3.634517    0.521832      Maritime       TG03    Togo       None
# 3    6.668877    1.425894      Plateaux       TG04    Togo       None
# 4    4.966938    0.707204  Savanes_Togo       TG05    Togo       None
#
#   ADM1ALT2FR ADM0_FR ADM0_PCODE        date     validOn validTo  \
# 0       None    Togo         TG  2020-12-16  2021-01-07    None
# 1       None    Togo         TG  2020-12-16  2021-01-07    None
# 2       None    Togo         TG  2020-12-16  2021-01-07    None
# 3       None    Togo         TG  2020-12-16  2021-01-07    None
# 4       None    Togo         TG  2020-12-16  2021-01-07    None
#
#                                             geometry
# 0  POLYGON ((1.43697 9.29300, 1.44455 9.28421, 1....
# ...

# %%
# Create a map centered on Cote d'Ivoire
my_map_civ = folium.Map(location=[7.5, -5.5], zoom_start=5)

print(civ.head())

civ.rename(columns={'adm1_name': 'admin1Name'}, inplace=True)

# Add the ISIBF scores to the GeoDataFrame
civ['ISIBF'] = civ['admin1Name'].map(values_civ_norm)

# Plot the map
folium.Choropleth(
    geo_data=civ,
    name='choropleth',
    data=civ,
    columns=['admin1Name', 'ISIBF'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    line_weight=2,
    legend_name='ISIBF score'
).add_to(my_map_civ)

# Add a tooltip to display information
folium.GeoJson(
    civ.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF'] is not None else 'gray',
        'color': 'grey',
        'weight': 0.5,
        'fillOpacity': 0.2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF'],
        aliases=['Region:', 'ISIBF Score:'],
        localize=True,
    )
).add_to(my_map_civ)



# Update the DataFrame for the combined map
#civ['ISIBF'] = civ['admin1Name'].map(values_civ_norm)

# Convert to GeoJSON
geojson_data = civ.__geo_interface__

# Plotly Choropleth Map for Togo
fig = px.choropleth_mapbox(
    civ,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='ISIBF',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 7.5, "lon": -5.5},  # Center on Togo
    title="Score d'accès aux agences bancaires par régions en Côte d'Ivoire",
    hover_name="admin1Name",  # Region names
    hover_data={'ISIBF': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'ISIBF': 'ISIBF Score'},
    color_continuous_scale=px.colors.sequential.Blues,  # Light to dark blue color scale
)

# Save as HTML
#html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/isibf_civ.html'
#fig.write_html(html_file_path)
# Out:
#          country             adm1_name         SOURCE    DATE_MAJ  \
# 0  Côte d'Ivoire           Savanes_CIV  OpenStreetMap  2022-04-11
# 1  Côte d'Ivoire                Zanzan  OpenStreetMap  2021-07-17
# 2  Côte d'Ivoire     Vallée du Bandama  OpenStreetMap  2020-01-02
# 3  Côte d'Ivoire  District du Denguélé  OpenStreetMap  2022-04-15
# 4  Côte d'Ivoire               Abidjan  OpenStreetMap  2021-10-28
#
#                                             geometry
# 0  POLYGON ((-6.24619 10.74020, -6.24339 10.73836...
# 1  POLYGON ((-2.52462 8.43977, -2.51587 8.38475, ...
# 2  POLYGON ((-4.95447 8.92226, -4.76309 8.91833, ...
# 3  POLYGON ((-7.72657 9.07268, -7.72656 9.07282, ...
# 4  POLYGON ((-4.10173 5.23567, -4.10278 5.23556, ...

# %%
# Create a map centered on Ghana
my_map = folium.Map(location=[8.5, -2], zoom_start=5)

# Add the ISIBF scores to the GeoDataFrame

benin_togo_civ['ISIBF'] = benin_togo_civ['admin1Name'].map(scores_dep_combined_norm)


# Plot the map
folium.Choropleth(
    geo_data=benin_togo_civ,
    name='choropleth',
    data=benin_togo_civ,
    columns=['admin1Name', 'ISIBF'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    line_weight=2,
    legend_name='ISIBF score'
).add_to(my_map)

# Add a tooltip to display information
folium.GeoJson(
    benin_togo_civ.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF'] is not None else 'gray',
        'color': 'grey',
        'weight': 0.5,
        'fillOpacity': 0.2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF'],
        aliases=['Region:', 'ISIBF Score:'],
        localize=True,
    )
).add_to(my_map)

# Save the map as an HTML file
#my_map.save("/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/Dashboard/isibf_benin_togo_civ_norm.html")


#benin_togo_civ['ISIBF'] = benin_togo_civ['admin1Name'].map(scores_dep_combined_norm)

# Convert to GeoJSON
geojson_data = benin_togo_civ.__geo_interface__

fig = px.choropleth_mapbox(
    benin_togo_civ,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='ISIBF',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 8.5, "lon": -2},
    title="Score d'accès aux agences bancaires par régions",
    hover_name="admin1Name",  # Region names
    hover_data={'ISIBF': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'ISIBF': 'ISIBF Score'},
    color_continuous_scale=px.colors.sequential.Blues,  # Light to dark blue color scale
)

# Save as HTML
#html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/isibf_combined.html'

# Save the map as HTML
#fig.write_html(html_file_path)

"""
# Now add the reference to navigation.js and the Back to Dashboard button
with open(html_file_path, 'r') as file:
    content = file.read()

# Create the Back to Dashboard button HTML
back_button = '<a href="index.html" class="back-button">Retour</a>\n'

# Create the <head> section with linked CSS and JavaScript
head_section = '''
<head>
    <link rel="stylesheet" href="style.css">
    <script src="navigation.js"></script>
</head>
'''

# Insert the <head> section into the content only if it exists
if '<head>' in content:
    content = content.replace('<head>', head_section)
else:
    # If <head> does not exist, prepend it (this might create an invalid HTML structure)
    content = head_section + content

# Insert the back button into the body at the top
if '<body>' in content:
    content = content.replace('<body>', '<body>' + back_button)

# Save the modified content back to the HTML file
with open(html_file_path, 'w') as file:
    file.write(content)

print(f"Map generated and saved to {html_file_path} with navigation.js included.")


"""
# Out:
# '\n# Now add the reference to navigation.js and the Back to Dashboard button\nwith open(html_file_path, \'r\') as file:\n    content = file.read()\n\n# Create the Back to Dashboard button HTML\nback_button = \'<a href="index.html" class="back-button">Retour</a>\n\'\n\n# Create the <head> section with linked CSS and JavaScript\nhead_section = \'\'\'\n<head>\n    <link rel="stylesheet" href="style.css">\n    <script src="navigation.js"></script>\n</head>\n\'\'\'\n\n# Insert the <head> section into the content only if it exists\nif \'<head>\' in content:\n    content = content.replace(\'<head>\', head_section)\nelse:\n    # If <head> does not exist, prepend it (this might create an invalid HTML structure)\n    content = head_section + content\n\n# Insert the back button into the body at the top\nif \'<body>\' in content:\n    content = content.replace(\'<body>\', \'<body>\' + back_button)\n\n# Save the modified content back to the HTML file\nwith open(html_file_path, \'w\') as file:\n  
# ...

# %%
"""
#benin_togo_civ=benin_togo_civ.rename(columns={'adm1_name': 'admin1Name'})


# Calculer les scores ISIBF pour le Bénin
alpha = max(alpha_benin, alpha_togo, alpha_civ)
threshold = 200 

#min max normalization
def normalize_scores(scores):
    min_score = min(scores.values())
    max_score = max(scores.values())
    return {city: (score - min_score) / (max_score - min_score) for city, score in scores.items()}

# Calculer les scores ISIBF pour le Bénin
isibf_scores_benin = calculate_isibf1(nb_agencies_benin, neighbors_benin, alpha, threshold)
scores_dep_benin = {department_mapping_benin[city]: score for city, score in isibf_scores_benin.items()}


# Calculer les scores ISIBF pour le Togo
isibf_scores_togo = calculate_isibf1(nb_agencies_togo, neighbors_togo, alpha, threshold)
scores_dep_togo = {department_mapping_togo[city]: score for city, score in isibf_scores_togo.items()}

# Calculer les scores ISIBF pour la Côte d'Ivoire en utilisant le mapping des départements pour le nombre d'agences
isibf_scores_civ = calculate_isibf1(nb_agencies_civ, neighbors_civ, alpha, threshold)
"""
isibf_scores_all= {**values_dep_benin, **values_dep_togo, **values_civ}
print(values_dep_togo)

scores_dep_combined_all=normalize_scores(isibf_scores_all)
scores_dep_combined_all = {dep: round(score, 2) for dep, score in scores_dep_combined_all.items()}

color_scale=px.colors.sequential.Blues


"""map Benin"""

#create a map centered on benin
my_map_benin2 = folium.Map(location=[9.5, 2.3], zoom_start=5)

benin['ISIBF2'] = benin['admin1Name'].map(scores_dep_combined_all)

# Plot the map
folium.Choropleth(
    geo_data=benin,
    name='choropleth',
    data=benin,
    columns=['admin1Name', 'ISIBF2'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    line_weight=2,
    legend_name='ISIBF score'
).add_to(my_map_benin2)

# Add a tooltip to display information
folium.GeoJson(
    benin.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF2'] is not None else 'gray',
        'color': 'grey',
        'weight': 0.5,
        'fillOpacity': 0.2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF2'],
        aliases=['Region:', 'Score:'],
        localize=True,
    )
).add_to(my_map_benin2)

# Convert to GeoJSON
geojson_data = benin.__geo_interface__

fig = px.choropleth_mapbox(
    benin,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='ISIBF2',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 9.5, "lon": 2.3},
    title="Score d'accès aux agences bancaires par régions au Bénin (normalisation globale)",
    hover_name="admin1Name",  # Region names
    hover_data={'ISIBF2': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'ISIBF2': 'Score'},
    color_continuous_scale=color_scale,
    range_color=[0, 1]
)

# Save the map as HTML
#fig.write_html('/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/isibf2_benin.html')


"""map Togo"""

# Create a map centered on Togo
my_map_togo2 = folium.Map(location=[8.5, 1.2], zoom_start=5)

# Add the ISIBF scores to the GeoDataFrame
togo['ISIBF2'] = togo['admin1Name'].map(scores_dep_combined_all)

# Plot the map
folium.Choropleth(
    geo_data=togo,
    name='choropleth',
    data=togo,
    columns=['admin1Name', 'ISIBF2'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    line_weight=2,
    legend_name='ISIBF score'
).add_to(my_map_togo2)

# Add a tooltip to display information
folium.GeoJson(
    togo.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF2'] is not None else 'gray',
        'color': 'grey',
        'weight': 0.5,
        'fillOpacity': 0.2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF2'],
        aliases=['Region:', 'Score:'],
        localize=True,
    )
).add_to(my_map_togo2)

# Convert to GeoJSON
geojson_data = togo.__geo_interface__


# Plotly Choropleth Map for Togo
fig = px.choropleth_mapbox(
    togo,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='ISIBF2',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 8.5, "lon": 1.2},  # Center on Togo
    title="Score d'accès aux agences bancaires par régions au Togo (normalisation globale)",
    hover_name="admin1Name",  # Region names
    hover_data={'ISIBF2': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'ISIBF2': 'Score'},
    color_continuous_scale=color_scale,
    range_color=[0, 1]
)

# Save as HTML
#fig.write_html('/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/isibf2_togo.html')


"""map Côte d'Ivoire"""

# Create a map centered on Cote d'Ivoire
my_map_civ2 = folium.Map(location=[7.5, -5.5], zoom_start=5)

# Add the ISIBF scores to the GeoDataFrame
civ['ISIBF2'] = civ['admin1Name'].map(scores_dep_combined_all)

# Plot the map
folium.Choropleth(
    geo_data=civ,
    name='choropleth',
    data=civ,
    columns=['admin1Name', 'ISIBF2'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    line_weight=2,
    legend_name='ISIBF score'
).add_to(my_map_civ2)

# Add a tooltip to display information
folium.GeoJson(
    civ.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF2'] is not None else 'gray',
        'color': 'grey',
        'weight': 0.5,
        'fillOpacity': 0.2,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF2'],
        aliases=['Region:', 'Score:'],
        localize=True,
    )
).add_to(my_map_civ2)

# Convert to GeoJSON
geojson_data = civ.__geo_interface__

# Plotly Choropleth Map for Togo
fig = px.choropleth_mapbox(
    civ,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='ISIBF2',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 7.5, "lon": -5.5},  # Center on Togo
    title="Score d'accès aux agences bancaires par régions en Côte d'Ivoire (normalisation globale)",
    hover_name="admin1Name",  # Region names
    hover_data={'ISIBF2': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'ISIBF2': 'Score'},
    color_continuous_scale=color_scale,
    range_color=[0, 1]
)

# Save as HTML
#fig.write_html('/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/isibf2_civ.html')
# Out:
# {'Kara': 7.145697926990774, 'Centrale': 6.880050241925157, 'Plateaux': 6.581072142194284, 'Maritime': 7.830527420843798, 'Savanes_Togo': 5.1716673609864685}

# %%
import folium
import plotly.express as px

# Rename column to match the GeoJSON property
benin_togo_civ = benin_togo_civ.rename(columns={'adm1_name': 'admin1Name'})

# Create a map centered on the region
my_map = folium.Map(location=[8.5, -2], zoom_start=5)

# Add the ISIBF scores to the GeoDataFrame
benin_togo_civ['ISIBF'] = benin_togo_civ['admin1Name'].map(scores_dep_combined_all)

# Add a Choropleth layer
folium.Choropleth(
    geo_data=benin_togo_civ.__geo_interface__,  # Ensure you're using the GeoDataFrame
    name='choropleth',
    data=benin_togo_civ,
    columns=['admin1Name', 'ISIBF'],
    key_on='feature.properties.admin1Name',
    fill_color='YlGn',
    fill_opacity=0.9,
    line_opacity=0.2,
    line_weight=2,
    legend_name='ISIBF score',
).add_to(my_map)

# Add GeoJson with tooltips
folium.GeoJson(
    benin_togo_civ.__geo_interface__,
    style_function=lambda feature: {
        'fillColor': 'YlGn' if feature['properties']['ISIBF'] is not None else 'gray',
        'color': 'grey',
        'weight': 0.5,
        'fillOpacity': 0.5,
    },
    tooltip=folium.GeoJsonTooltip(
        fields=['admin1Name', 'ISIBF'],
        aliases=['Region:', 'ISIBF Score:'],
        localize=True,
    )
).add_to(my_map)

# Save the Folium map as an HTML file
#my_map.save("/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/Dashboard/Bénin/isibf_benin_togo_civ.html")

# Create a Plotly choropleth map
geojson_data = benin_togo_civ.__geo_interface__

fig = px.choropleth_mapbox(
    benin_togo_civ,
    geojson=geojson_data,
    locations='admin1Name',
    featureidkey='properties.admin1Name',
    color='ISIBF',
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 8.5, "lon": -2},
    title="Score d'accès aux agences bancaires par régions (normalisé sur les trois pays)",
    hover_name="admin1Name",
    hover_data={'ISIBF': True, 'admin1Name': False},
    labels={'admin1Name': 'Région', 'ISIBF': 'ISIBF Score'},
    color_continuous_scale=px.colors.sequential.Blues,
)

# Save as HTML
#html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/isibf2_combined.html'

# Save the map as HTML
#fig.write_html(html_file_path)

"""
# Now add the reference to navigation.js and the Back to Dashboard button
with open(html_file_path, 'r') as file:
    content = file.read()

# Create the Back to Dashboard button HTML
back_button = '<a href="index.html" class="back-button">Retour</a>\n'

# Create the <head> section with linked CSS and JavaScript
head_section = '''
<head>
    <link rel="stylesheet" href="style.css">
    <script src="navigation.js"></script>
</head>
'''

# Insert the <head> section into the content only if it exists
if '<head>' in content:
    content = content.replace('<head>', head_section)
else:
    # If <head> does not exist, prepend it (this might create an invalid HTML structure)
    content = head_section + content

# Insert the back button into the body at the top
if '<body>' in content:
    content = content.replace('<body>', '<body>' + back_button)

# Save the modified content back to the HTML file
with open(html_file_path, 'w') as file:
    file.write(content)

print(f"Map generated and saved to {html_file_path} with navigation.js included.")
"""
# Out:
# '\n# Now add the reference to navigation.js and the Back to Dashboard button\nwith open(html_file_path, \'r\') as file:\n    content = file.read()\n\n# Create the Back to Dashboard button HTML\nback_button = \'<a href="index.html" class="back-button">Retour</a>\n\'\n\n# Create the <head> section with linked CSS and JavaScript\nhead_section = \'\'\'\n<head>\n    <link rel="stylesheet" href="style.css">\n    <script src="navigation.js"></script>\n</head>\n\'\'\'\n\n# Insert the <head> section into the content only if it exists\nif \'<head>\' in content:\n    content = content.replace(\'<head>\', head_section)\nelse:\n    # If <head> does not exist, prepend it (this might create an invalid HTML structure)\n    content = head_section + content\n\n# Insert the back button into the body at the top\nif \'<body>\' in content:\n    content = content.replace(\'<body>\', \'<body>\' + back_button)\n\n# Save the modified content back to the HTML file\nwith open(html_file_path, \'w\') as file:\n  
# ...

# %%
# population benin, 2015
population_benin = {
    'Alibori': 867463,
    'Atakora': 772262,
    'Atlantique': 1398229,
    'Borgou': 1212249,
    'Collines': 717477,
    'Couffo':745328,
    'Donga':543130,
    'Littoral': 679012,
    'Mono':497243,
    'Oueme':1100404,
    'Plateau':622372,
    'Zou':851580
}

# population togo, 2022
population_togo = {
    'Kara': 985512,
    'Centrale': 795529,
    'Maritime': 1346615+2188376,
    'Plateaux': 1635946,
    'Savanes_Togo': 1143520
}

#population Cote d'Ivoire, 2021
population_civ = {
    'Abidjan': 6321017,
    'Bas-Sassandra': 2687176,
    'Comoé': 1501336,
    'District du Denguélé': 436015,
    'Gôh-Djiboua': 2088440,
    'Lacs': 1488531,
    'Lagunes': 2042623,
    'Montagnes': 3027023,
    'Sassandra-Marahoué': 2720876,
    'Savanes_CIV': 2159434,
    'Vallée du Bandama': 1964929,
    'Woroba': 1184813,
    'Yamoussoukro': 422072,
    'Zanzan': 1344865
}

# calculate population over 15 years old for each country, knowing that each country has 57% of its population over 15 years old
population_benin_over_15 = {dep: 0.57 * pop for dep, pop in population_benin.items()}
population_togo_over_15 = {dep: 0.57 * pop for dep, pop in population_togo.items()}
population_civ_over_15 = {dep: 0.57 * pop for dep, pop in population_civ.items()}

# %%
# Superficies des régions du Bénin
superficie_benin = {
    'Alibori': 26242,
    'Atakora': 20499,
    'Atlantique': 3233,
    'Borgou': 25856,
    'Collines': 13931,
    'Couffo': 2404,
    'Donga': 11126,
    'Littoral': 79,
    'Mono': 1605,
    'Oueme': 1281,
    'Plateau': 3264,
    'Zou': 5243
}

# Superficies des régions du Togo
superficie_togo = {
    'Maritime': 6100,
    'Plateaux': 16975,
    'Centrale': 13182,
    'Kara': 11738,
    'Savanes_Togo': 8602
}

# Superficies des districts de la Côte d'Ivoire
superficie_civ = {
    'Abidjan': 2119,
    'Bas-Sassandra': 26680,
    'Comoé': 14200,
    'District du Denguélé': 20600,
    'Gôh-Djiboua': 21300,
    'Lacs': 12190,
    'Lagunes': 13323,
    'Montagnes': 16600,
    'Sassandra-Marahoué': 19840,
    'Savanes_CIV': 40210,
    'Vallée du Bandama': 28530,
    'Woroba': 31140,
    'Yamoussoukro': 3500,
    'Zanzan': 38000
}

# %%
# indicateur de nombre d'agences par région 

"""
# Indicateur géographique
def indicateur_geo(nb_agences, areas):
    ind_scores = {}
    for area in areas:
        if area in nb_agences and area in areas:  # Vérification des clés
            # Calcul du score géographique pour chaque région/district
            ind_scores[area] = (nb_agences[area] / areas[area]) * 1000  # Nombre d'agences par 100 km² 
        else:
            ind_scores[area] = None  # Ou une autre valeur pour indiquer une absence de données
    return ind_scores


geo_civ = indicateur_geo(nb_agencies_civ, superficie_civ)
geo_civ = {dep: np.ceil(score) for dep, score in geo_civ.items()}
print(geo_civ)
geo_benin = indicateur_geo(nb_agencies_benin, superficie_benin)
geo_togo = indicateur_geo(nb_agencies_togo, superficie_togo)


geo_combined = {**geo_benin, **geo_togo, **geo_civ} 

"""

# indicateur démographique
def indicateur_demo(nb_agences, population, mapping, ref):
    ind_scores = {}
    for dep in nb_agences:  # Itérer sur les départements ou régions
        # Vérifier si le département est dans le mapping
        if dep in mapping:
            region = mapping[dep]  # Trouver la région correspondante dans le mapping
        else:
            region = dep  # Si le département n'a pas besoin de mapping, on l'utilise tel quel
        
        # Calculer l'indicateur démographique
        ind_scores[dep] = (nb_agences[dep] / population[region]) * ref  # Nombre d'agences par 1000 habitants
    
    return ind_scores

#implement a second demographic indicator that uses the number of agencies in an area within a certain catchment area delimited by a threshold around the capital, per 100000 inhabitants 
def indicateur_demo2(nb_agences, population, mapping, neighbors, threshold=threshold, ref=100000):
    """
    Calculate a demographic indicator based on the number of agencies in neighboring cities within a certain catchment area.

    Parameters:
    nb_agences (dict): A dictionary where keys are districts and values are the number of agencies in those districts.
    population (dict): A dictionary where keys are districts and values are the population of those districts.
    mapping (dict): A dictionary mapping capital cities to their corresponding districts.
    neighbors (dict): A dictionary mapping each city to a list of its neighboring cities.
    threshold (float): The distance threshold around the capital (in the same unit as the agencies' locations).
    ref (int): The reference population (default is 100,000).

    Returns:
    dict: A dictionary where keys are districts and values are the calculated demographic indicator.
    """
    # Initialize the result dictionary
    demo_indicator = {}

    # Iterate over each capital and its corresponding district
    for capital, district in mapping.items():
        if district in nb_agences and district in population:
            # Get the number of agencies and population for the district of the capital
            agencies = nb_agences[district]
            pop = population[district]

            # Initialize total agencies and total population within the threshold
            total_agencies = agencies
            total_population = pop

            # Add agencies and populations from neighboring cities
            for neighbor in neighbors.get(capital, []):
                if neighbor in nb_agences and neighbor in population:
                    total_agencies += nb_agences[neighbor]
                    total_population += population[neighbor]

            # Calculate the demographic indicator based on the catchment area
            if total_population > 0:  # Avoid division by zero
                indicator_value = (total_agencies / total_population) * ref
                demo_indicator[district] = indicator_value
            else:
                demo_indicator[district] = 0  # If population is zero, set indicator to 0

    return demo_indicator

# Example data to use with the function
nb_agences = {
    'Abidjan': 12, 'Bas-Sassandra': 5, 'Comoé': 8, 'Denguélé': 3,
    'Gôh-Djiboua': 4, 'Lacs': 2, 'Lagunes': 6, 'Montagnes': 1,
    'Sassandra-Marahoué': 3, 'Savanes': 9, 'Vallée du Bandama': 7,
    'Woroba': 2, 'Yamoussoukro': 4, 'Zanzan': 1
}

population = {
    'Abidjan': 5000000, 'Bas-Sassandra': 1500000, 'Comoé': 1200000, 'Denguélé': 800000,
    'Gôh-Djiboua': 900000, 'Lacs': 600





def format_scores(scores, mapping):
    return {mapping.get(city, city): np.ceil(score) for city, score in scores.items()}


demo_benin = format_scores(indicateur_demo(nb_agencies_benin, population_benin_over_15, department_mapping_benin, 100000), department_mapping_benin)
demo_togo = format_scores(indicateur_demo(nb_agencies_togo, population_togo_over_15, department_mapping_togo, 100000), department_mapping_togo)
demo_civ = indicateur_demo(nb_agencies_civ, population_civ_over_15, department_mapping_civ, 300000)
#round scores for demo_civ
demo_civ = {dep: np.ceil(score) for dep, score in demo_civ.items()}
demo_combined = {**demo_benin, **demo_togo, **demo_civ}

#demo_combined_norm = normalize_scores(demo_combined)

#print(demo_combined)

# %%
benin_togo_civ['Indicateur_demographique'] = benin_togo_civ['admin1Name'].map(demo_combined)

# Tracer la carte avec les scores ISIBF
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
benin_togo_civ.plot(column='ISIBF', ax=ax, legend=True, cmap='Blues', 
         legend_kwds={'label': 'Nombre équipements'}, edgecolor='grey')

ax.set_title('Nombres agences pour 100 000 habitants')
plt.show()

# %%
import pandas as pd
import plotly.express as px

# Inversion du dictionnaire pour obtenir régions -> chefs-lieux
region_to_cheflieu_benin = {region: chef_lieu for chef_lieu, region in department_mapping_benin.items()}

# Exemple de données (remplacez par vos données réelles)
data_benin = {
    'admin1Name': list(demo_benin.keys()),
    'Indicateur_demographique_benin': list(demo_benin.values()),
    'ChefLieu': [region_to_cheflieu_benin[region] for region in demo_benin.keys()]
}

# Création du DataFrame
benin = pd.DataFrame(data_benin)

# Création du graphique en barres avec une couleur unique
fig = px.bar(
    benin,
    x='admin1Name',
    y='Indicateur_demographique_benin',
    labels={'admin1Name': 'Région', 'Indicateur_demographique_benin': "Nombre d'agences pour 100 000 habitants"},
    title="Nombre d'agences pour 100 000 habitants par région au Bénin",
    hover_data={'ChefLieu': True},  # Ajout des chefs-lieux en sous-label dans le survol
    color_discrete_sequence=["#4C78A8"]  # Couleur unique pour toutes les barres (bleu)
)

# Mise en page du graphique
fig.update_layout(
    xaxis_title="Région",
    yaxis_title="Nombre d'agences pour 100 000 habitants"
)
# Exporter le graphique en HTML pour intégration dans le site web
html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique_benin.html'
fig.write_html(html_file_path)

print(f"Graphique exporté avec succès dans {html_file_path}")
# Out:
# Graphique exporté avec succès dans /Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique_benin.html

# %%
region_to_cheflieu_togo = {region: chef_lieu for chef_lieu, region in department_mapping_togo.items()}

# Exemple de données (remplacez par vos données réelles)
data_togo = {
    'admin1Name': list(demo_togo.keys()),
    'Indicateur_demographique_togo': list(demo_togo.values()),
    'ChefLieu': [region_to_cheflieu_togo[region] for region in demo_togo.keys()]
}

# Création du DataFrame
togo = pd.DataFrame(data_togo)

# Création du graphique en barres avec une couleur unique
fig = px.bar(
    togo,
    x='admin1Name',
    y='Indicateur_demographique_togo',
    labels={'admin1Name': 'Région', 'Indicateur_demographique_benin': "Nombre d'agences pour 100 000 habitants"},
    title="Nombre d'agences pour 100 000 habitants par région au Togo",
    hover_data={'ChefLieu': True},  # Ajout des chefs-lieux en sous-label dans le survol
    color_discrete_sequence=["#4C78A8"]  # Couleur unique pour toutes les barres (bleu)
)

# Mise en page du graphique
fig.update_layout(
    xaxis_title="Région",
    yaxis_title="Nombre d'agences pour 100 000 habitants"
)
# Exporter le graphique en HTML pour intégration dans le site web
html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique_togo.html'
fig.write_html(html_file_path)

print(f"Graphique exporté avec succès dans {html_file_path}")
# Out:
# Graphique exporté avec succès dans /Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique_togo.html

# %%
import pandas as pd
import plotly.express as px

# Inversion du dictionnaire pour obtenir région -> chef-lieu pour la Côte d'Ivoire
region_to_cheflieu_civ = {region: chef_lieu for chef_lieu, region in department_mapping_civ.items()}

# Exemple de données pour la Côte d'Ivoire (remplacez par vos données réelles)
data_civ = {
    'admin1Name': list(demo_civ.keys()),
    'Indicateur_demographique_civ': list(demo_civ.values()),
    'ChefLieu': [region_to_cheflieu_civ.get(region, 'Inconnu') for region in demo_civ.keys()]
}

# Création du DataFrame pour la Côte d'Ivoire
civ = pd.DataFrame(data_civ)

# Création du graphique en barres pour la Côte d'Ivoire avec une couleur unique
fig = px.bar(
    civ,
    x='admin1Name',
    y='Indicateur_demographique_civ',
    labels={'admin1Name': 'Région', 'Indicateur_demographique_civ': "Nombre d'agences pour 100 000 habitants"},
    title="Nombre d'agences pour 100 000 habitants par région en Côte d'Ivoire",
    hover_data={'ChefLieu': True},  # Ajout des chefs-lieux en sous-label dans le survol
    color_discrete_sequence=["#4C78A8"]  # Couleur unique pour toutes les barres (bleu)
)

# Mise en page du graphique
fig.update_layout(
    xaxis_title="Région",
    yaxis_title="Nombre d'agences pour 100 000 habitants"
)

# Exporter le graphique en HTML pour intégration dans le site web
html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique_civ.html'
fig.write_html(html_file_path)

print(f"Graphique exporté avec succès dans {html_file_path}")
# Out:
# Graphique exporté avec succès dans /Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique_civ.html

# %%
# Construction des données pour le DataFrame combiné
data = []
for region, score in demo_benin.items():
    data.append({'Region': region, 'Indicateur_demographique': score, 'Pays': 'Bénin', 
                 'ChefLieu': region_to_cheflieu_benin.get(region, 'Inconnu')})
for region, score in demo_togo.items():
    data.append({'Region': region, 'Indicateur_demographique': score, 'Pays': 'Togo', 
                 'ChefLieu': region_to_cheflieu_togo.get(region, 'Inconnu')})
for region, score in demo_civ.items():
    data.append({'Region': region, 'Indicateur_demographique': score, 'Pays': 'Côte d\'Ivoire', 
                 'ChefLieu': department_mapping_civ.get(region, 'Inconnu')})
    

data2 = {}
for region, score in demo_combined.items():
    data2[region] = score

# Conversion en DataFrame
df = pd.DataFrame(data)


print(data2)

# Création du graphique en barres avec la possibilité de sélectionner les pays
fig = px.bar(
    df,
    x='Region',  # Utilise uniquement le nom de la région sans les chefs-lieux
    y='Indicateur_demographique',
    color='Pays',
    barmode='group',
    labels={'Region': 'Région', 'Indicateur_demographique': "Nombre d'agences pour 100 000 habitants"},
    title="Comparaison du nombre d'agences pour 100 000 habitants par région",
    color_discrete_sequence=["#4C78A8", "#F58518", "#54A24B"]  # Couleurs pour chaque pays
)

# Mise en page du graphique avec personnalisation
fig.update_layout(
    xaxis_title="Région",
    yaxis_title="Nombre d'agences pour 100 000 habitants",
    legend_title_text="Pays",
    margin=dict(l=40, r=40, t=60, b=100)  # Ajustement de la marge inférieure si besoin
)


# Exporter le graphique en HTML pour intégration dans le site web
html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique_combined.html'
fig.write_html(html_file_path)

print(f"Graphique exporté avec succès dans {html_file_path}")
# Out:
# {'Alibori': 2.0, 'Atakora': 1.0, 'Atlantique': 3.0, 'Borgou': 2.0, 'Collines': 1.0, 'Couffo': 1.0, 'Donga': 1.0, 'Littoral': 32.0, 'Mono': 3.0, 'Oueme': 4.0, 'Plateau': 0.0, 'Zou': 3.0, 'Kara': 4.0, 'Centrale': 3.0, 'Plateaux': 2.0, 'Maritime': 6.0, 'Savanes_Togo': 3.0, 'Abidjan': 33.0, 'Bas-Sassandra': 8.0, 'Comoé': 10.0, 'District du Denguélé': 3.0, 'Gôh-Djiboua': 6.0, 'Lacs': 3.0, 'Lagunes': 4.0, 'Montagnes': 3.0, 'Sassandra-Marahoué': 5.0, 'Savanes_CIV': 6.0, 'Vallée du Bandama': 6.0, 'Woroba': 2.0, 'Yamoussoukro': 14.0, 'Zanzan': 1.0}
# Graphique exporté avec succès dans /Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique_combined.html

# %%
"""
benin_togo_civ['Indicateur_demographique'] = benin_togo_civ['admin1Name'].map(demo_combined)

# Convert to GeoJSON
geojson_data = benin_togo_civ.__geo_interface__

fig = px.choropleth_mapbox(
    benin_togo_civ,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='Indicateur_demographique',  # Fill color with ISIBF scores
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 8.5, "lon": -2},
    title="Nombre d'agences bancaires pour 100 000 habitants",
    hover_name="admin1Name",  # Region names
    hover_data={'Indicateur_demographique': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région','Indicateur_demographique': "Nombre d'agences"},
    color_continuous_scale=px.colors.sequential.Blues,  # Light to dark blue color scale
)

# Save as HTML
html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/indicateur_demographique.html'

# Save the map as HTML
fig.write_html(html_file_path)


# Now add the reference to navigation.js and the Back to Dashboard button
with open(html_file_path, 'r') as file:
    content = file.read()

# Create the Back to Dashboard button HTML
back_button = '<a href="index.html" class="back-button">Retour</a>\n'

# Create the <head> section with linked CSS and JavaScript
head_section = '''
<head>
    <link rel="stylesheet" href="style.css">
    <script src="navigation.js"></script>
</head>
'''

# Insert the <head> section into the content only if it exists
if '<head>' in content:
    content = content.replace('<head>', head_section)
else:
    # If <head> does not exist, prepend it (this might create an invalid HTML structure)
    content = head_section + content

# Insert the back button into the body at the top
if '<body>' in content:
    content = content.replace('<body>', '<body>' + back_button)

# Save the modified content back to the HTML file
with open(html_file_path, 'w') as file:
    file.write(content)

print(f"Map generated and saved to {html_file_path} with navigation.js included.")

"""
# Out:
# '\n# Now add the reference to navigation.js and the Back to Dashboard button\nwith open(html_file_path, \'r\') as file:\n    content = file.read()\n\n# Create the Back to Dashboard button HTML\nback_button = \'<a href="index.html" class="back-button">Retour</a>\n\'\n\n# Create the <head> section with linked CSS and JavaScript\nhead_section = \'\'\'\n<head>\n    <link rel="stylesheet" href="style.css">\n    <script src="navigation.js"></script>\n</head>\n\'\'\'\n\n# Insert the <head> section into the content only if it exists\nif \'<head>\' in content:\n    content = content.replace(\'<head>\', head_section)\nelse:\n    # If <head> does not exist, prepend it (this might create an invalid HTML structure)\n    content = head_section + content\n\n# Insert the back button into the body at the top\nif \'<body>\' in content:\n    content = content.replace(\'<body>\', \'<body>\' + back_button)\n\n# Save the modified content back to the HTML file\nwith open(html_file_path, \'w\') as file:\n  
# ...

# %%
# Create a mask for regions with 0 agencies
benin_togo_civ['is_zero'] = benin_togo_civ['Indicateur_demographique'] == 0

# Convert to GeoJSON
geojson_data = benin_togo_civ.__geo_interface__

color_map = {
    True: 'dark red',
    False: 'white'
}

fig = px.choropleth_mapbox(
    benin_togo_civ,
    geojson=geojson_data,
    locations='admin1Name',  # Location column in your GeoDataFrame
    featureidkey='properties.admin1Name',  # This should match the GeoJSON structure
    color='is_zero', #apply a mask to show only regions with 0 agencies
    mapbox_style="carto-positron",
    zoom=5,
    center={"lat": 8.5, "lon": -2},
    title="Régions sans aucune agence bancaire",
    hover_name="admin1Name",  # Region names
    hover_data={'is_zero': True, 'admin1Name': False},  # Show ISIBF score but hide original name
    labels={'admin1Name': 'Région', 'is_zero': 'Sans agence'},
    color_discrete_map=color_map
)

# Remove the legend
fig.update_traces(showlegend=False)

# Save as HTML
html_file_path = '/Users/haouabenaliabbo/Desktop/M2 IREN/ALTERNANCE/GitHub/Dashboard-West-Africa/docs/no_agencies.html'

# Save the map as HTML
fig.write_html(html_file_path)

"""

# Now add the reference to navigation.js and the Back to Dashboard button
with open(html_file_path, 'r') as file:
    content = file.read()

# Create the Back to Dashboard button HTML
back_button = '<a href="index.html" class="back-button">Retour</a>\n'

# Create the <head> section with linked CSS and JavaScript
head_section = '''
<head>
    <link rel="stylesheet" href="style.css">
    <script src="navigation.js"></script>
</head>
'''

# Insert the <head> section into the content only if it exists
if '<head>' in content:
    content = content.replace('<head>', head_section)
else:
    # If <head> does not exist, prepend it (this might create an invalid HTML structure)
    content = head_section + content

# Insert the back button into the body at the top
if '<body>' in content:
    content = content.replace('<body>', '<body>' + back_button)

# Save the modified content back to the HTML file
with open(html_file_path, 'w') as file:
    file.write(content)

print(f"Map generated and saved to {html_file_path} with navigation.js included.")

"""
# Out:
# '\n\n# Now add the reference to navigation.js and the Back to Dashboard button\nwith open(html_file_path, \'r\') as file:\n    content = file.read()\n\n# Create the Back to Dashboard button HTML\nback_button = \'<a href="index.html" class="back-button">Retour</a>\n\'\n\n# Create the <head> section with linked CSS and JavaScript\nhead_section = \'\'\'\n<head>\n    <link rel="stylesheet" href="style.css">\n    <script src="navigation.js"></script>\n</head>\n\'\'\'\n\n# Insert the <head> section into the content only if it exists\nif \'<head>\' in content:\n    content = content.replace(\'<head>\', head_section)\nelse:\n    # If <head> does not exist, prepend it (this might create an invalid HTML structure)\n    content = head_section + content\n\n# Insert the back button into the body at the top\nif \'<body>\' in content:\n    content = content.replace(\'<body>\', \'<body>\' + back_button)\n\n# Save the modified content back to the HTML file\nwith open(html_file_path, \'w\') as file:\n
# ...
